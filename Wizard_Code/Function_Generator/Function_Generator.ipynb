# %%
from scipy import *
from scipy import signal
from pylab import *
from wave import *
import struct
import numpy as np
from scipy.io.wavfile import read
import matplotlib.pyplot as plt
#from mpl_toolkits.mplot3d import Axes3D
# %matplotlib notebook

import matplotlib.pyplot as plt

# %% [markdown]
# # Pre-Defined Waves:

# %%
#Example Sawtooth Wave
t = linspace(0, 1, num = 1000, endpoint = False)
plt.ylim(-1.5, 1.5)
plt.plot(t, signal.sawtooth((2 * np.pi) * 5 * t))
#Where the 5 controls the frequency of the wave
# Out:
# <img src="data:image/png;base64,...">

# %%
#Example Sine Wave
t = linspace(0, 1, num = 1000, endpoint = False)
plt.ylim(-1.5, 1.5)
plt.plot(np.sin((2 * np.pi) * t))
# Out:
# <img src="data:image/png;base64,...">

# %%
#Example Square Wave
t = linspace(0, 1, num = 1000, endpoint = False)
plt.ylim(-1.5, 1.5)
plt.plot(t, signal.square((2 * np.pi) * 5 * t))
#Where the 5 controls the frequency of the wave
# Out:
# <img src="data:image/png;base64,...">

# %%
#Example Square Wave with modulation
sig = np.sin(2 * np.pi * t)
pwm = signal.square(2 * np.pi * 30 * t, duty=(sig + 1)/2)
plt.plot(t, sig)
plt.plot(t, pwm)
plt.ylim(-1.5, 1.5)

plt.plot(pwm)
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# # Generating Random Waveforms: [INCOMPLETE]

# %% [markdown]
# I stopped here after I half-heartedly made the wave definitions because whatever. But I want to impliment the thinkdsp.random_seed([x]) function here for the random-value generators for the functions.

# %%
t = np.zeros

def Sine(t):
    
    np.sin
    return Sawtooth

def awtooth(t, ramp):
    
    signal.sawtooth(2 * np.pi * 5 * t)
    return Sawtooth
#Here, ramp is the rate at which the slope inclines-- 1 producies a rising slope while 0 produces a negative slope. 
# if ramp= 0.5, it produces a triangle wave. 

def Square(t, cycle):
    
    signal.square(2 * np.pi * 5 * t)
    return Sawtooth
# Cycle is the duty cycle. If it's an array it'll change the shape of the array over time, and should be the same 
#length as 't'

# %% [markdown]
# # In PyAudio:

# %%
import pyaudio
import numpy as np

p = pyaudio.PyAudio()

volume = 0.5     # Range [0.0, 1.0]
fs = 44100       # Sampling rate in Hz, must be integer
duration = 1.0   # Seconds, may be a float?
f = 440.0        # Frequency in Hz, may be float?

# Sample Generation, example is sine wave
samples = (np.sin(2*np.pi*np.arange(fs*duration)*f/fs)).astype(np.float32)

# For thw paFloat32, sample values must be in range [-1.0, 1.0]
stream = p.open(format=pyaudio.paFloat32,
                channels=1,
                rate=fs,
                output=True)

# Plays file, could aslo write to file
stream.write(volume*samples)

stream.stop_stream()
stream.close()

p.terminate()
