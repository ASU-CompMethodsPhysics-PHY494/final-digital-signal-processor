# %%
import numpy as np 
import scipy.misc
rac = scipy.misc.face() 

import matplotlib.pyplot as plt

# %%
# %matplotlib inline
plt.gray()
plt.imshow(rac)

# %%
from matplotlib import pyplot as plt


fourier = np.fft.fft2(stair)
fourier_shift = np.fft.fftshift(fourier)
mag = 20*np.log(np.abs(fourier_shift))
plt.subplot(121),plt.imshow(stair, cmap = 'gray')
plt.title('Original'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(mag, cmap = 'gray')
plt.title('Mag'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
rac[0][0] # 0 row, 0 col
# Out:
# array([121, 112, 131], dtype=uint8)

# %%
def average(pixel):
    return (pixel[0] + pixel[1] + pixel[2]) / 3

def weightedAverage(pixel):
    return 0.299*pixel[0] + 0.587*pixel[1] + 0.114*pixel[2]

# %%
image=rac
grey = np.zeros((image.shape[0], image.shape[1])) # init 2D numpy array
# get row number
for rownum in range(len(image)):
    for colnum in range(len(image[rownum])):
        grey[rownum][colnum] = average(image[rownum][colnum])
# Out:
# /Users/trevorvanengelhoven/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:2: RuntimeWarning: overflow encountered in ubyte_scalars
#   from ipykernel import kernelapp as app

# %%
import matplotlib.cm as cm # 
import matplotlib

plt.imshow(grey, cmap = matplotlib.cm.Greys_r)
plt.show()

# %%
fourier = np.fft.fft2(stair)
fourier_shift = np.fft.fftshift(fourier)
mag = 20*np.log(np.abs(fourier_shift))
plt.subplot(121),plt.imshow(stair, cmap = 'gray')
plt.title('Original'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(mag, cmap = 'gray')
plt.title('Mag'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
stair = scipy.misc.ascent()
plt.gray()
plt.imshow(stair)

# %%
f = np.fft.fft2(stair)
fshift = np.fft.fftshift(f)
magnitude_spectrum = 20*np.log(np.abs(fshift))

plt.subplot(121),plt.imshow(stair, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(magnitude_spectrum, cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
magnitude_spectrum1=(magnitude_spectrum.copy()/100)-2
m2=magnitude_spectrum1.copy()[256,:]
m2=np.append(m2,m2)
m2=np.append(m2,m2)

plt.plot(m2)
